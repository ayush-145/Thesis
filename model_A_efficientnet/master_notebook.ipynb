# %% [markdown]
# # Master Notebook — model_A_efficientnet
# > Universal execution on **Google Colab** or **Kaggle**.

# %%
# !pip install albumentations==1.4.1
# !pip install timm

# %%
import os
import sys

IS_KAGGLE = "KAGGLE_KERNEL_RUN_TYPE" in os.environ
if not IS_KAGGLE:
    try:
        from google.colab import drive
        drive.mount('/content/drive')
        # !rsync -av /content/drive/MyDrive/DR_Thesis/model_A_efficientnet/ ./
    except ImportError:
        print("Not on Colab/Kaggle, running locally.")
else:
    import glob
    code_dirs = glob.glob("/kaggle/input/**/*code*/", recursive=True)
    if code_dirs:
        # !rsync -av {code_dirs[0]} ./

# %%
# !python train.py

# %%
# !python evaluate.py
